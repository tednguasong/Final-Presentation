# %%
# Just importing the necessary packages to start
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import csv

# %%
# Opening, reading, and making the Person Dataset 
data = open("C:\\Users\\User\\Desktop\\pppub19.csv")
ppdf = pd.read_csv(data)
ppdf
# Out:
#                       PERIDNUM  GESTCEN  PH_SEQ  GTCBSA  P_SEQ  A_LINENO  \
# 0        100069124539430000000       11       4       0      1         1
# 1       3999403901610020000000       11       6       0      1         1
# 2       9119340093206090000000       11       7       0      1         1
# 3       1410320300969990000000       11       8       0      1         1
# 4       1410320300969990000000       11       8       0      2         2
# ...                        ...      ...     ...     ...    ...       ...
# 180096  5977501577211010000000       95   94632   46520      4         4
# 180097  5977501577211010000000       95   94632   46520      5         5
# 180098  5977501577211010000000       95   94632   46520      6         6
# 180099  5789403901611010000000       95   94633   46520      1         1
# 180100  5789403901611010000000       95   94633   46520      2         2
#
#         PF_SEQ  PHF_SEQ  OED_TYP1  OED_TYP2  ...  I_DISVL1  I_DISVL2  \
# ...

# %%
#Drops the uneccessary columns from the Person dataframe
ppdf.drop(['GESTCEN', 'GTCBSA', 'A_LINENO', 'PF_SEQ', 'OED_TYP1', 'OED_TYP2', 'OED_TYP3', 'PERRP', 'PXRRP', 'PXMARITL', 'PXRACE1', 
         'PXHSPNON', 'PEAFEVER', 'PXAFEVER', 'PEAFWHN1', 'PXAFWHN1', 'PEAFWHN2', 'PEAFWHN3', 'PEAFWHN4', 'PXSPOUSE', 'PENATVTY', 
         'PXNATVTY', 'PEMNTVTY', 'PXMNTVTY', 'PEFNTVTY', 'PXFNTVTY', 'PEINUSYR', 'PXINUSYR', 'PRPERTYP', 'PRCITFLG', 'PRCITSHP', 
         'PECOHAB', 'PXCOHAB', 'PEABSRSN', 'PEHRUSLT', 'PRDISC', 'PRPTREA', 'PRUNTYPE', 'PEIO1COW', 'PRCOW1', 'PRERELG', 'PRWERNAL', 
         'PRHERNAL', 'PEDISEAR', 'PEDISEYE', 'PEDISREM',  'PEDISPHY', 'PEDISDRS', 'PEDISOUT', 'PXDISEAR', 'PXDISEYE', 'PXDISREM', 
         'PXDISPHY', 'PXDISDRS', 'PXDISOUT', 'PRDISFLG', 'PECERT1', 'PECERT2', 'PECERT3', 'PXCERT1', 'PXCERT2', 'PXCERT3', 'PEPAR1', 
         'PEPAR2', 'PEPAR1TYP', 'PEPAR2TYP', 'PXPAR1', 'PXPAR2', 'PXPAR1TYP', 'PXPAR2TYP', 'A_DTIND', 'A_HRSPAY', 'A_PAYABS', 
         'A_WANTJB', 'A_HRLYWK', 'A_MJIND', 'A_UNMEM', 'A_MJOCC', 'A_DTOCC', 'A_UNCOV', 'A_FNLWGT', 'A_ERNLWT', 'A_FAMREL', 'A_FAMNUM', 
         'AXAGE', 'AXSEX', 'AXLFSR', 'AXHRS', 'AXWHYABS', 'AXPAYABS', 'AXCLSWKR', 'AXNLFLJ', 'AXUSLHRS', 'AXUNMEM', 'AXUNCOV', 'AXENRLW', 
         'AXHSCOL', 'AXFTPT', 'AXHGA', 'AXHRLYWK', 'A_USLHRS', 'A_FAMTYP', 'A_GRSWK', 'A_WKSLK', 'A_SPOUSE', 'A_MARITL', 'A_HRS1', 
         'A_USLFT',  'A_FTLF', 'A_UNTYPE', 'A_CLSWKR', 'A_EXPRRP', 'A_WHYABS', 'A_PFREL', 'A_WHENLJ', 'A_NLFLJ', 'MARSUPWT', 'ACTC_CRD', 
         'AGI', 'ANN_VAL', 'ANN_YN', 'CAID', 'CAP_VAL', 'CAP_YN', 'CHAMPVA', 'CHCARE_YN', 'CHELSEW_YN', 'CHSP_VAL', 'CHSP_YN', 'CLWK', 
         'COV', 'COV_CYR', 'COV_MULT_CYR', 'CSP_VAL', 'CSP_YN', 'CTC_CRD', 'DBTN_VAL', 'DEPDIR', 'DEPGRP', 'DEPMIL', 'DEPMRK', 'DEPMRKS', 
         'DEPMRKUN', 'DEPNONM', 'DEPPRIV', 'DIR', 'DIRFTYP', 'DIRFTYP2', 'DIRLIN1', 'DIROUT', 'DIS_HP', 'DIS_SC1', 'DIS_SC2', 'DIS_VAL1', 
         'DIS_VAL2', 'DIS_YN', 'DIV_VAL', 'DIV_YN', 'DSAB_VAL', 'DST_SC1', 'DST_SC2', 'DST_SC1_YNG', 'DST_SC2_YNG', 'DST_VAL1', 'DST_VAL2', 
         'DST_VAL1_YNG', 'DST_VAL2_YNG', 'DST_YN', 'DST_YN_YNG', 'EARNER', 'ED_VAL', 'ED_YN', 'EIT_CRED', 'ERN_OTR', 'ERN_SRCE', 'ERN_VAL', 
         'ERN_YN', 'FAMREL', 'FEDTAX_AC', 'FEDTAX_BC', 'FED_RET', 'FICA', 'FIN_VAL', 'FIN_YN', 'FRMOTR', 'FRM_VAL', 'FRSE_VAL', 'FRSE_YN', 
         'GRP', 'GRPFTYP', 'GRPFTYP2', 'GRPLIN1', 'GRPOUT', 'HEA', 'HHDFMX', 'HHDREL', 'HIPAID', 'HRCHECK', 'HRSWK', 'IHSFLG', 'INDUSTRY', 
         'INT_VAL', 'INT_YN', 'I_ANNVAL', 'I_ANNYN', 'I_CAID', 'I_CAPVAL', 'I_CAPYN', 'I_CHAMPVA', 'I_CHCAREYN', 'I_CHELSEWYN', 'I_CHSPVAL', 
         'I_CHSPYN', 'I_CSPVAL', 'I_CSPYN', 'I_DEPDIR', 'I_DEPGRP', 'I_DEPMIL', 'I_DEPMRK', 'I_DEPMRKS', 'I_DEPMRKUN', 'I_DEPNONM', 
         'I_DEPPRIV', 'I_DIR', 'I_DIROUT', 'I_DISCS', 'I_DISHP', 'I_DISSC1', 'I_DISSC2', 'I_DISYN', 'I_DIVVAL', 'I_DIVYN', 'I_DSTSC', 
         'I_DSTSCCOMP', 'I_DSTVAL1COMP', 'I_DSTVAL2COMP', 'I_DSTYNCOMP', 'I_EDTYP', 'I_EDYN', 'I_ERNSRC', 'I_ERNVAL', 'I_ERNYN', 'I_FINVAL', 
         'I_FINYN', 'I_FRMVAL', 'I_FRMYN', 'I_GRP', 'I_GRPOUT', 'I_HEA', 'I_HIPAID', 'I_HRCHK', 'I_HRSWK', 'I_IHSFLG', 'I_INDUS', 'I_INTVAL', 
         'I_INTYN', 'I_LJCW', 'I_LKSTR', 'I_LKWEEK', 'I_LOSEWK', 'I_MCAID', 'I_MCARE', 'I_MCPREM', 'I_MIG1', 'I_MIG2', 'I_MIG3', 'I_MIL', 
         'I_MILOUT', 'I_MOOP', 'I_MOOP2', 'I_MRK', 'I_MRKOUT', 'I_MRKS', 'I_MRKSOUT', 'I_MRKUN', 'I_MRKUNOUT', 'I_NOEMP', 'I_NONM', 
         'I_NONMOUT', 'I_NOW_CAID', 'I_NOW_CHAMPVA', 'I_NOW_DEPDIR', 'I_NOW_DEPGRP', 'I_NOW_DEPMIL', 'I_NOW_DEPMRK', 'I_NOW_DEPMRKS', 
         'I_NOW_DEPMRKUN', 'I_NOW_DEPNONM', 'I_NOW_DEPPRIV', 'I_NOW_DIR', 'I_NOW_DIROUT', 'I_NOW_GRP', 'I_NOW_GRPOUT', 'I_NOW_HIPAID', 
         'I_NOW_IHSFLG', 'I_NOW_MCAID', 'I_NOW_MCARE', 'I_NOW_MIL', 'I_NOW_MILOUT', 'I_NOW_MRK', 'I_NOW_MRKOUT', 'I_NOW_MRKS', 'I_NOW_MRKSOUT',
         'I_NOW_MRKUN', 'I_NOW_MRKUNOUT', 'I_NOW_NONM', 'I_NOW_NONMOUT', 'I_NOW_OTHMT', 'I_NOW_OUTDIR', 'I_NOW_OUTGRP', 'I_NOW_OUTMIL', 
         'I_NOW_OUTMRK', 'I_NOW_OUTMRKS', 'I_NOW_OUTMRKUN', 'I_NOW_OUTNONM', 'I_NOW_OUTPRIV', 'I_NOW_OWNDIR', 'I_NOW_OWNGRP', 'I_NOW_OWNMIL', 
         'I_NOW_OWNMRK', 'I_NOW_OWNMRKS', 'I_NOW_OWNMRKUN', 'I_NOW_OWNNONM', 'I_NOW_OWNPRIV', 'I_NOW_PCHIP', 'I_NOW_PRIV', 'I_NOW_PUB', 
         'I_NOW_VACARE', 'I_NWLKWK', 'I_NWLOOK', 'I_NXTRES', 'I_OCCUP', 'I_OEDVAL', 'I_OIVAL', 'I_OTHMT', 'I_OUTDIR', 'I_OUTGRP', 'I_OUTMIL', 
         'I_OUTMRK', 'I_OUTMRKS', 'I_OUTMRKUN', 'I_OUTNONM', 'I_OUTPRIV', 'I_OWNDIR', 'I_OWNGRP', 'I_OWNMIL', 'I_OWNMRK', 'I_OWNMRKS', 
         'I_OWNMRKUN', 'I_OWNNONM', 'I_OWNPRIV', 'I_PAWMO', 'I_PAWTYP', 'I_PAWVAL', 'I_PAWYN', 'I_PCHIP', 'I_PECOULD', 'I_PENINC', 'I_PENPLA', 
         'I_PENSC1', 'I_PENSC2', 'I_PENVAL1', 'I_PENVAL2', 'I_PENYN', 'I_PEOFFER', 'I_PEWNELIG1', 'I_PEWNELIG2', 'I_PEWNELIG3', 'I_PEWNELIG4', 
         'I_PEWNELIG5', 'I_PEWNELIG6', 'I_PEWNTAKE1', 'I_PEWNTAKE2', 'I_PEWNTAKE3', 'I_PEWNTAKE4', 'I_PEWNTAKE5', 'I_PEWNTAKE6', 'I_PEWNTAKE7', 
         'I_PEWNTAKE8', 'I_PHIPVAL', 'I_PHIPVAL2', 'I_PHMEMP', 'I_PMEDVAL', 'I_POTCVAL', 'I_PRIV', 'I_PTRSN', 'I_PTWKS', 'I_PTYN', 'I_PUB', 
         'I_PYRSN', 'I_RETCBVAL', 'I_RETCBYN', 'I_RINTSC', 'I_RINTVAL1', 'I_RINTVAL2', 'I_RINTYN', 'I_RNTVAL', 'I_RNTYN', 'I_RSNNOT', 'I_SEVAL', 
         'I_SEYN', 'I_SSIVAL', 'I_SSIYN', 'I_SSVAL', 'I_SSYN', 'I_SURSC1', 'I_SURSC2', 'I_SURYN', 'I_UCVAL', 'I_UCYN', 'I_VACARE', 'I_VETQVA', 
         'I_VETTYP', 'I_VETVAL', 'I_VETYN', 'I_WCTYP', 'I_WCVAL' , 'I_WCYN', 'I_WKCHK', 'I_WKSWK', 'I_WORKYN', 'I_WSVAL', 'I_WSYN', 'I_WTEMP', 
         'LJCW', 'LKNONE', 'LKSTRCH', 'LKWEEKS', 'LOSEWKS', 'MARG_TAX', 'MCAID', 'MCAID_CYR', 'MCARE', 'MIGSAME', 'MIG_DIV', 'MIG_MTR1', 'MIG_MTR3', 
         'MIG_MTR4', 'MIG_ST', 'MIL', 'MILFTYP', 'MILFTYP2', 'MILLIN1', 'MILOUT', 'MOOP', 'MOOP2', 'MRK', 'MRKFTYP', 'MRKFTYP2', 'MRKLIN1', 'MRKOUT', 
         'MRKS', 'MRKSFTYP', 'MRKSFTYP2', 'MRKSLIN1', 'MRKSOUT', 'MRKUN', 'MRKUNFTYP', 'MRKUNFTYP2', 'MRKUNLIN1', 'MRKUNOUT', 'NOCOV_CYR', 'NOEMP', 
         'NONM', 'NONMFTYP', 'NONMFTYP2', 'NONMLIN1', 'NONMOUT', 'NOW_CAID', 'NOW_CHAMPVA', 'NOW_COV', 'NOW_DEPDIR', 'NOW_DEPGRP', 'NOW_DEPMIL', 
         'NOW_DEPMRK', 'NOW_DEPMRKS', 'NOW_DEPMRKUN', 'NOW_DEPNONM', 'NOW_DEPPRIV', 'NOW_DIR', 'NOW_DIRFTYP', 'NOW_DIRFTYP2', 'NOW_DIRLIN', 'NOW_DIROUT', 
         'NOW_GRP', 'NOW_GRPFTYP', 'NOW_GRPFTYP2', 'NOW_GRPLIN', 'NOW_GRPOUT', 'NOW_HIPAID', 'NOW_IHSFLG', 'NOW_MCAID', 'NOW_MCARE', 'NOW_MIL', 
         'NOW_MILFTYP', 'NOW_MILFTYP2', 'NOW_MILLIN', 'NOW_MILOUT', 'NOW_MRK', 'NOW_MRKFTYP', 'NOW_MRKFTYP2', 'NOW_MRKLIN', 'NOW_MRKOUT', 'NOW_MRKS', 
         'NOW_MRKSFTYP', 'NOW_MRKSFTYP2', 'NOW_MRKSLIN', 'NOW_MRKSOUT', 'NOW_MRKUN', 'NOW_MRKUNFTYP', 'NOW_MRKUNFTYP2', 'NOW_MRKUNLIN', 'NOW_MRKUNOUT', 
         'NOW_NONM', 'NOW_NONMFTYP', 'NOW_NONMFTYP2', 'NOW_NONMLIN', 'NOW_NONMOUT', 'NOW_OTHMT', 'NOW_OUTDIR', 'NOW_OUTGRP', 'NOW_OUTMIL', 'NOW_OUTMRK', 
         'NOW_OUTMRKS', 'NOW_OUTMRKUN', 'NOW_OUTNONM', 'NOW_OUTPRIV', 'NOW_OWNDIR', 'NOW_OWNGRP', 'NOW_OWNMIL', 'NOW_OWNMRK', 'NOW_OWNMRKS', 'NOW_OWNMRKUN', 
         'NOW_OWNNONM', 'NOW_OWNPRIV', 'NOW_PCHIP', 'NOW_PRIV', 'NOW_PUB', 'NOW_VACARE', 'NWLKWK', 'NWLOOK', 'OCCUP', 'OI_OFF', 'OI_VAL', 'OI_YN', 'OTHMT', 
         'OUTDIR', 'OUTGRP', 'OUTMIL', 'OUTMRK', 'OUTMRKS', 'OUTMRKUN', 'OUTNONM', 'OUTPRIV', 'OWNDIR', 'OWNGRP', 'OWNMIL', 'OWNMRK', 'OWNMRKS', 'OWNMRKUN', 
         'OWNNONM', 'OWNPRIV', 'PARENT', 'PAW_MON', 'PAW_TYP', 'PAW_VAL', 'PAW_YN', 'PCHIP', 'PCHIP_SP2', 'PEARNVAL', 'PECOULD', 'PEMCPREM', 'PENINCL', 
         'PENPLAN', 'PEN_SC1', 'PEN_SC2', 'PEN_VAL1', 'PEN_VAL2', 'PEN_YN', 'PEOFFER', 'PERLIS', 'PEWNELIG1', 'PEWNELIG2', 'PEWNELIG3', 'PEWNELIG4', 'PEWNELIG5', 
         'PEWNELIG6', 'PEWNTAKE1', 'PEWNTAKE2', 'PEWNTAKE3', 'PEWNTAKE4', 'PEWNTAKE5', 'PEWNTAKE6', 'PEWNTAKE7', 'PEWNTAKE8', 'PHIP_VAL', 'PHIP_VAL2', 'PHMEMPRS', 
         'PMED_VAL', 'PNSN_VAL', 'POCCU2', 'POTC_VAL', 'POTHVAL', 'POV_UNIV', 'PPPOS', 'PRECORD', 'PRIV', 'PRIV_CYR', 'PRSWKXPNS', 'PTOTVAL', 'PTOT_R', 'PTRSN', 
         'PTWEEKS', 'PTYN', 'PUB', 'PUB_CYR', 'PYRSN', 'RESNSS1', 'RESNSS2', 'RESNSSA', 'RESNSSI1', 'RESNSSI2', 'RESNSSIA','RETCB_VAL', 'RETCB_YN', 'RINT_SC1', 
         'RINT_SC2', 'RINT_VAL1', 'RINT_VAL2', 'RINT_YN', 'RNT_VAL', 'RNT_YN', 'SEMP_VAL', 'SEMP_YN', 'SEOTR', 'SE_VAL', 'SPM_ACTC', 'SPM_CAPHOUSESUB', 
         'SPM_CHILDCAREXPNS', 'SPM_CHILDSUPPD', 'SPM_EITC', 'SPM_ENGVAL', 'SPM_EQUIVSCALE', 'SPM_FAMTYPE', 'SPM_FEDTAX', 'SPM_FEDTAXBC', 'SPM_FICA', 'SPM_GEOADJ', 
         'SPM_HAGE', 'SPM_HEAD', 'SPM_HHISP', 'SPM_HMARITALSTATUS', 'SPM_HRACE', 'SPM_ID', 'SPM_MEDXPNS', 'SPM_NUMADULTS', 'SPM_NUMKIDS', 'SPM_NUMPER', 'SPM_POOR', 
         'SPM_POVTHRESHOLD', 'SPM_RESOURCES', 'SPM_SCHLUNCH', 'SPM_SNAPSUB', 'SPM_STTAX', 'SPM_TENMORTSTATUS', 'SPM_TOTVAL', 'SPM_WCOHABIT', 'SPM_WEIGHT', 
         'SPM_WFOSTER22', 'SPM_WICVAL', 'SPM_WKXPNS', 'SPM_WNEWHEAD', 'SPM_WNEWPARENT', 'SPM_WUI_LT15', 'SRVS_VAL', 'SSI_VAL', 'SSI_YN', 'SS_VAL', 'SS_YN', 
         'STATETAX_A', 'STATETAX_B', 'STRKUC', 'SUBUC', 'SUR_SC1', 'SUR_SC2', 'SUR_VAL1', 'SUR_VAL2', 'SUR_YN', 'TAX_INC', 'TRDINT_VAL', 'UC_VAL', 'UC_YN', 'VACARE', 
         'VET_QVA', 'VET_TYP1', 'VET_TYP2', 'VET_TYP3', 'VET_TYP4', 'VET_TYP5', 'VET_VAL', 'VET_YN', 'WAGEOTR', 'WC_TYPE', 'WC_VAL', 'WC_YN', 'WECLW', 'WEIND', 'WELKNW', 
         'WEMIND', 'WEMOCG', 'WEUEMP', 'WEWKRS', 'WEXP', 'WICYN', 'WICYNA', 'WKCHECK', 'WKSWORK', 'WORKYN', 'WRK_CK', 'WSAL_VAL', 'WSAL_YN', 'WS_VAL', 'WTEMP', 'FL_665', 
         'SPM_CAPWKCCXPNS', 'TPEN_VAL1', 'TPEN_VAL2', 'TANN_VAL', 'TDST_VAL1', 'TDST_VAL2', 'TDST_VAL1_YNG', 'TDST_VAL2_YNG', 'TFIN_VAL',  'TOI_VAL', 'TTRDINT_VAL', 'TRINT_VAL1', 
         'TRINT_VAL2', 'TRNT_VAL', 'TCAP_VAL', 'TDIV_VAL', 'TCSP_VAL', 'TED_VAL', 'TCHSP_VAL', 'TPHIP_VAL', 'TPHIP_VAL2', 'TPMED_VAL', 'TPOTC_VAL', 'TPEMCPREM', 'TCERNVAL', 
         'TCWSVAL', 'TCSEVAL', 'TCFFMVAL', 'TSURVAL1', 'TSURVAL2', 'TDISVAL1', 'TDISVAL2', 'TAX_ID', 'PEIOIND', 'PEIOOCC', 'A_WERNTF', 'A_HERNTF', 'I_DISVL1', 'I_DISVL2', 
         'I_SURVL1', 'I_SURVL2', 'MIG_CBST', 'MIG_DSCP', 'DEP_STAT', 'FILEDATE', 'FILESTAT', 'MMYY'], axis = 1, inplace = True)

ppdf
# Out:
#                       PERIDNUM  PH_SEQ  P_SEQ  PHF_SEQ  PEHSPNON  PRDASIAN  \
# 0        100069124539430000000       4      1        1         2        -1
# 1       3999403901610020000000       6      1        1         2        -1
# 2       9119340093206090000000       7      1        1         2        -1
# 3       1410320300969990000000       8      1        1         2        -1
# 4       1410320300969990000000       8      2        1         2        -1
# ...                        ...     ...    ...      ...       ...       ...
# 180096  5977501577211010000000   94632      4        2         2         3
# 180097  5977501577211010000000   94632      5        2         2         3
# 180098  5977501577211010000000   94632      6        2         2         3
# 180099  5789403901611010000000   94633      1        1         2         4
# 180100  5789403901611010000000   94633      2        1         2         5
#
# ...

# %%
# Opening, reading, and making the Household Dataset 
data_2 = open("C:\\Users\\User\\Desktop\\hhpub19.csv")
hhdf = pd.read_csv(data_2)
hhdf
# Out:
#                     H_IDNUM  GEREG  GESTFIPS  GEDIV  HEFAMINC  H_MONTH  \
# 0       2031046575209900000      1        23      1        -1        3
# 1      11000302225345300000      1        23      1        -1        3
# 2       2031054530232100000      1        23      1        -1        3
# 3       1000691245394300000      1        23      1         6        3
# 4      14320203005595200000      1        23      1        -1        3
# ...                     ...    ...       ...    ...       ...      ...
# 94628   2135501431031610000      4        15      9        14        3
# 94629  95527750177110100000      4        15      9         1        3
# 94630  17707592110755100000      4        15      9         1        3
# 94631  59775015772110100000      4        15      9        13        3
# 94632  57894039016110100000      4        15      9         6        3
#
#        H_YEAR  H_TENURE  H_HHNUM  H_LIVQRT  ...  THPROP_VAL  GTCBSA  GTCO  \
# ...

# %%
#Dropping the uneccessary columns in the Household dataframe
hhdf.drop(['GEDIV', 'HEFAMINC', 'H_MONTH', 'H_YEAR', 'H_TENURE', 'H_HHNUM', 'H_LIVQRT',
         'H_RESPNM', 'H_TELHHD', 'H_TELAVL', 'H_TELINT', 'H1TENURE', 'H1LIVQRT', 
         'H1TELHHD', 'H1TELAVL', 'H1TELINT', 'H_HHTYPE', 'H_TYPEBC', 'H_MIS', 
         'GESTCEN', 'HANNVAL', 'HANN_YN', 'HCHCARE_VAL', 'HCHCARE_YN', 'HCOV',
         'HCSPVAL', 'HCSP_YN', 'HDISVAL', 'HDIS_YN', 'HDIVVAL', 'HDIV_YN', 'HDSTVAL', 
         'HDST_YN', 'HEARNVAL', 'HEDVAL', 'HED_YN', 'HENGAST', 'HENGVAL', 'HFDVAL', 
         'HFINVAL', 'HFIN_YN', 'HFLUNCH', 'HFLUNNO', 'HFOODMO', 'HFOODNO', 'HFOODSP', 
         'HFRVAL', 'HH5TO18', 'HHINC', 'HHOTLUN', 'HHOTNO', 'HHSTATUS', 'HH_HI_UNIV', 
         'HINC_FR', 'HINC_SE', 'HINC_UC', 'HINC_WC', 'HINC_WS', 'HINTVAL', 'HINT_YN', 
         'HLORENT', 'HMCAID', 'HNUMFAM', 'HOIVAL', 'HOI_YN', 'HOTHVAL', 'HPAWVAL', 
         'HPAW_YN', 'HPCTCUT', 'HPENVAL', 'HPEN_YN', 'HPRES_MORT', 'HPRIV', 'HPROP_VAL', 
         'HPUB', 'HPUBLIC', 'HRECORD', 'HRNTVAL', 'HRNT_YN', 'HRNUMWIC', 'HRWICYN', 
         'HSEVAL', 'HSSIVAL', 'HSSI_YN', 'HSSVAL', 'HSS_YN', 'HSUP_WGT', 'HSURVAL', 
         'HSUR_YN', 'HTOP5PCT', 'HTOTVAL', 'HUCVAL', 'HUNDER15', 'HUNDER18', 'HUNITS', 
         'HVETVAL', 'HVET_YN', 'HWCVAL', 'HWSVAL', 'I_CHCAREVAL', 'I_HENGAS', 'I_HENGVA', 
         'I_HFDVAL', 'I_HFLUNC', 'I_HFLUNN', 'I_HFOODM', 'I_HFOODN', 'I_HFOODS', 'I_HHOTLU', 
         'I_HHOTNO', 'I_HLOREN', 'I_HPUBLI', 'I_HUNITS', 'I_PROPVAL', 'NOW_HCOV', 'NOW_HMCAID', 
         'NOW_HPRIV', 'NOW_HPUB', 'HRHTYPE', 'THCHCARE_VAL', 'THPROP_VAL', 'GTCBSA', 'GTCO', 
         'GTCBSAST', 'GTCSA', 'GTINDVPC', 'FILEDATE', 'MMYY'], axis = 1, inplace = True)

hhdf
# Out:
#                     H_IDNUM  GEREG  GESTFIPS  H_NUMPER  H_SEQ  GTCBSASZ  \
# 0       2031046575209900000      1        23         0      1         0
# 1      11000302225345300000      1        23         0      2         0
# 2       2031054530232100000      1        23         0      3         0
# 3       1000691245394300000      1        23         1      4         0
# 4      14320203005595200000      1        23         0      5         0
# ...                     ...    ...       ...       ...    ...       ...
# 94628   2135501431031610000      4        15         1  94629         4
# 94629  95527750177110100000      4        15         2  94630         4
# 94630  17707592110755100000      4        15         6  94631         4
# 94631  59775015772110100000      4        15         6  94632         4
# 94632  57894039016110100000      4        15         2  94633         4
#
#        GTMETSTA
# 0             2
# 1             2
# 2             2
# 3             2
# ...

# %%
# Meant to change the last 2 digits of all the PERIDNUM values

# Convert the column to a list
plist = ppdf['PERIDNUM'].tolist()

# Removes the last 2 characters of each element in the list
pplist = [sub[ : -2] for sub in plist] 
    
# Creates a dataframe for the new PERIDNUM values
pid_df = pd.DataFrame(pplist, columns = ['PERIDNUM'])

# Inserts the new PERIDNUM values into the Person dataframe
ppdf['PERIDNUM'] = pid_df['PERIDNUM']
    
ppdf
# Out:
#                     PERIDNUM  PH_SEQ  P_SEQ  PHF_SEQ  PEHSPNON  PRDASIAN  \
# 0        1000691245394300000       4      1        1         2        -1
# 1       39994039016100200000       6      1        1         2        -1
# 2       91193400932060900000       7      1        1         2        -1
# 3       14103203009699900000       8      1        1         2        -1
# 4       14103203009699900000       8      2        1         2        -1
# ...                      ...     ...    ...      ...       ...       ...
# 180096  59775015772110100000   94632      4        2         2         3
# 180097  59775015772110100000   94632      5        2         2         3
# 180098  59775015772110100000   94632      6        2         2         3
# 180099  57894039016110100000   94633      1        1         2         4
# 180100  57894039016110100000   94633      2        1         2         5
#
#         PRDTHSP  PRDTRACE  PEMLR  PRWKSTAT  ...  A_HGA  P_STAT  A_CIVLF  \
# ...

# %%
# Overall meant to change column names between the 
# Person and Household Dataframes for merging later

#Renaming the column PERIDNUM in the Person df
ppdf.rename(columns={"PERIDNUM": "IDNUM"}, inplace = True)

#Renaming the column H_IDNUM in the Household df
hhdf.rename(columns={"H_IDNUM": "IDNUM"}, inplace = True)

# %%
# Merges the Person and Household DF's 
# Matches values with the IDNUM columns
merged_df = pd.merge(ppdf,hhdf,on = 'IDNUM')
merged_df
# Out:
#                        IDNUM  PH_SEQ  P_SEQ  PHF_SEQ  PEHSPNON  PRDASIAN  \
# 0        1000691245394300000       4      1        1         2        -1
# 1       39994039016100200000       6      1        1         2        -1
# 2       91193400932060900000       7      1        1         2        -1
# 3       14103203009699900000       8      1        1         2        -1
# 4       14103203009699900000       8      2        1         2        -1
# ...                      ...     ...    ...      ...       ...       ...
# 220635  59775015772110100000   94632      4        2         2         3
# 220636  59775015772110100000   94632      5        2         2         3
# 220637  59775015772110100000   94632      5        2         2         3
# 220638  59775015772110100000   94632      6        2         2         3
# 220639  59775015772110100000   94632      6        2         2         3
#
#         PRDTHSP  PRDTRACE  PEMLR  PRWKSTAT  ...  DIS_CS  MIG_REG  NXTRES  \
# ...

# %%
# Looks for Males not in the experienced work force
print("Male and not in labor force:", len(merged_df.loc[(merged_df['A_SEX'] == 1) & (merged_df['A_EXPLF'] == 0)]))

# Looks for Males that are employed
print("Male and employed:", len(merged_df.loc[(merged_df['A_SEX'] == 1) & (merged_df['A_EXPLF'] == 1)]))

# Looks for Males that are unemployed
print("Male and unemployed:", len(merged_df.loc[(merged_df['A_SEX'] == 1) & (merged_df['A_EXPLF'] == 2)]))
# Out:
# Male and not in labor force: 51494
# Male and employed: 53420
# Male and unemployed: 2009

# %%
# Looks for Females not in the experienced work force
print("Female and not in labor force:", len(merged_df.loc[(merged_df['A_SEX'] == 2) & (merged_df['A_EXPLF'] == 0)]))

# Looks for Females that are employed
print("Female and employed:", len(merged_df.loc[(merged_df['A_SEX'] == 2) & (merged_df['A_EXPLF'] == 1)]))

# Looks for Females that are unemployed
print("Female and unemployed:", len(merged_df.loc[(merged_df['A_SEX'] == 2) & (merged_df['A_EXPLF'] == 2)]))
# Out:
# Female and not in labor force: 62076
# Female and employed: 50021
# Female and unemployed: 1620

# %%
# Multi plot of Employment Status by Sex

mlist = [51494, 53420, 2009]
flist = [62076, 50021, 1620]
employstat = ['Not in \nexperienced \nlabor force', 'Employed', 'Unemployed']

X_axis = np.arange(len(employstat))

plt.bar(X_axis - 0.2, mlist, 0.4, label = 'Males')
plt.bar(X_axis + 0.2, flist, 0.4, label = 'Females')
  
plt.xticks(X_axis, employstat)
plt.xlabel("Employment Status")
plt.ylabel("Number of People")
plt.title("Employment Status by Sex")
plt.legend()
plt.show()

# %%
unemploy_race = []

# Looks for Unemployed white only
unemploy_race.append(len(merged_df.loc[(merged_df['PRDTRACE'] == 1) & 
                                       (merged_df['A_EXPLF'] == 2)]))

# Looks for Unemployed black only:
unemploy_race.append(len(merged_df.loc[(merged_df['PRDTRACE'] == 2) & 
                                       (merged_df['A_EXPLF'] == 2)]))

# Looks for Unemployed American Indian, Alaskan Native only
unemploy_race.append(len(merged_df.loc[(merged_df['PRDTRACE'] == 3) & 
                                       (merged_df['A_EXPLF'] == 2)]))

# Looks for Unemployed asian only:
unemploy_race.append(len(merged_df.loc[(merged_df['PRDTRACE'] == 4) & 
                                       (merged_df['A_EXPLF'] == 2)]))

# Looks for Unemployed Hawaiian/Pacfic Islander only
unemploy_race.append(len(merged_df.loc[(merged_df['PRDTRACE'] == 5) & 
                                       (merged_df['A_EXPLF'] == 2)]))

# Looks for the unemployed mixed races
mixed = len(merged_df.loc[(merged_df['PRDTRACE'] == 6) & 
                  (merged_df['A_EXPLF'] == 2)])
i = 7
n = 27

while i < n:
    mixed += len(merged_df.loc[(merged_df['PRDTRACE'] == i) & (merged_df['A_EXPLF'] == 2)])
    i += 1
    
unemploy_race.append(mixed)
print(unemploy_race)
# Out:
# [2464, 768, 91, 160, 21, 125]

# %%
# Pie Chart for Unemployment by Race

labels = ['White', 'Black', 'American Indian, Alaskan Native', 'Asian', 'Hawaiian/Pacfic Islander', 'Mixed']
sizes = np.array([68, 21, 3, 4, 1, 3])
myexplode = (0.1, 0.2, 0.3, 0.3, 0.5, 0.5)

plt.pie(sizes, labels = labels, explode = myexplode, autopct='%1.1f%%', shadow = True)
plt.title("Unemployment Rate Percentage\n" + "Per Race in the US, 2019")
plt.show()

# %%
# Looks for not in labor force in metropoliton

NLB_MList = []
j = 2

while j < 8:
    NLB_MList.append(len(merged_df.loc[(merged_df['GTCBSASZ'] == j) & 
                              (merged_df['A_EXPLF'] == 0)]))
    j += 1


# Looks for employment in metropolitan
EMList = []
k = 2

while k < 8:
    EMList.append(len(merged_df.loc[(merged_df['GTCBSASZ'] == k) & 
                              (merged_df['A_EXPLF'] == 1)]))
    k += 1

# Looks for unemployment in metropolitan
UEMList = []
l = 2

while l < 8:
    UEMList.append(len(merged_df.loc[(merged_df['GTCBSASZ'] == l) & 
                              (merged_df['A_EXPLF'] == 2)]))
    l += 1

# %%
# Scatter plot for Employment and Metropolitan

fig = plt.figure(figsize=(12, 6))

x = np.array(NLB_MList)
y = np.array(['100,000 - 249,999', '250,000 - 499,999', '500,000 - 999,999', 
              '1,000,000 - 2,499,999', '2,500,000 - 4,999,999','5,000,000+'])
plt.scatter(x, y)


x = np.array(EMList)
y = np.array(['100,000 - 249,999', '250,000 - 499,999', '500,000 - 999,999', 
              '1,000,000 - 2,499,999', '2,500,000 - 4,999,999','5,000,000+'])
plt.scatter(x, y)


x = np.array(UEMList)

y = np.array(['100,000 - 249,999', '250,000 - 499,999', '500,000 - 999,999', 
              '1,000,000 - 2,499,999', '2,500,000 - 4,999,999','5,000,000+'])
plt.scatter(x, y)
plt.xlabel("Amount of People")
plt.ylabel("Metropolitan Area Size")
plt.title("Employment Status by Metropolitan Area Size")

plt.show()

# %%
# Meant for hiatorgram 

#Making dataframes for number of persons in household by unemployment
HistDF1 = merged_df.loc[(merged_df['H_NUMPER'] == 1) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF2 = merged_df.loc[(merged_df['H_NUMPER'] == 2) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF3 = merged_df.loc[(merged_df['H_NUMPER'] == 3) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF4 = merged_df.loc[(merged_df['H_NUMPER'] == 4) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF5 = merged_df.loc[(merged_df['H_NUMPER'] == 5) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF6 = merged_df.loc[(merged_df['H_NUMPER'] == 6) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF7 = merged_df.loc[(merged_df['H_NUMPER'] == 7) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF8 = merged_df.loc[(merged_df['H_NUMPER'] == 8) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF9 = merged_df.loc[(merged_df['H_NUMPER'] == 9) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF10 = merged_df.loc[(merged_df['H_NUMPER'] == 10) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF11 = merged_df.loc[(merged_df['H_NUMPER'] == 11) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF12 = merged_df.loc[(merged_df['H_NUMPER'] == 12) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF13 = merged_df.loc[(merged_df['H_NUMPER'] == 13) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF14 = merged_df.loc[(merged_df['H_NUMPER'] == 14) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF15 = merged_df.loc[(merged_df['H_NUMPER'] == 15) & 
                       (merged_df['A_EXPLF'] == 2)]
HistDF16 = merged_df.loc[(merged_df['H_NUMPER'] == 11) & 
                       (merged_df['A_EXPLF'] == 2)]

# %%
# Histogram For frequency of people in a household 

plt.figure(figsize = (20, 10))

plt.hist(HistDF1['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF2['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF3['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF4['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF5['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF6['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF7['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF8['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF9['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF10['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF11['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF12['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF13['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF14['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF15['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)
plt.hist(HistDF16['H_NUMPER'].tolist(), bins = 'auto', histtype = 'bar', rwidth = 0.9)

plt.xlabel('Number of persons in household')
plt.ylabel('Frequency')
plt.title('Frequecny of Number of Persons in Household That Have Unemployed Residents')
plt.show()

# %%
# Meant for Stack Plot Dealing with Age and employment stat

# ages that are not in labe forse

agenlf = []
j = 1

while j < 18:
    agenlf.append(len(merged_df.loc[(merged_df['AGE1'] == j) & 
                              (merged_df['A_EXPLF'] == 0)]))
    j += 1


# employed ages
agee = []
k = 1

while k < 18:
    agee.append(len(merged_df.loc[(merged_df['AGE1'] == k) & 
                              (merged_df['A_EXPLF'] == 1)]))
    k += 1

# unemployed ages
ageune = []
l = 1

while l < 18:
    ageune.append(len(merged_df.loc[(merged_df['AGE1'] == l) & 
                              (merged_df['A_EXPLF'] == 2)]))
    l += 1

# %%
# Actual STACK PLOT CODE

fig = plt.figure(figsize=(25, 10))

Ages = ['15', '16 & 17', '18 & 19', '20 & 21',
        '22 to 24', '25 to 29', '30 to 34', '35 to 39',
        '40 to 44','45 to 49', '50 to 54', '55 to 59',
        '60 to 61', '62 to 64','65 to 69','70 to 74',
        '75 & over']
plt.plot([], [], color = 'm', label = 'Not in Labor Force', linewidth = 5)
plt.plot([], [], color = 'c', label = 'Employed', linewidth = 5)
plt.plot([], [], color = 'r', label = 'Unemployed', linewidth = 5)

plt.stackplot(Ages, agenlf, agee, ageune, colors = ['m','c','r'])
plt.xlabel('Ages 15 and over')
plt.xlabel('Amount of People')
plt.title('Employment Status of people over the age of 15')
plt.legend()
plt.show()

# %%
# MEANT FOR UNEMPLOYMENT PERCENTAGE CHANGE BY STATES MULTIPLOT 

states_unempl = []
j = 1

while j < 57:
    states_unempl.append(len(merged_df.loc[(merged_df['GESTFIPS'] == j) & 
                              (merged_df['A_EXPLF'] == 2)]))
    j += 1

# %%
#BAR PLOT CODE
region_unempl = []
j = 1

while j < 5:
    region_unempl.append(len(merged_df.loc[(merged_df['GEREG'] == j) & 
                              (merged_df['A_EXPLF'] == 2)]))
    j += 1
    
region = ['Northeast','Midwest','South','West']

plt.bar(region, region_unempl, 0.4)
  
plt.xlabel("U.S. Regions")
plt.ylabel("Number of People Unemployed")
plt.title("Employment Status by Region in the United States")
plt.show()
